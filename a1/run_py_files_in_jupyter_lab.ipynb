# %%
# %run a1_paycheck_calculator.py
# Out:
# Paycheck Calculator
# Developer: Ayansewa Adedeji
# Program calculates net pay based upon hours worked, hourly rate, and taxes paid.
# Hours Worked:  40
# Hourly Rate: $ 50
# Tax Rate (percent):  25
# Program Output:
# Gross Pay: $2,000.00
# Tax Rate: 25.00%
# Tax Amount: $500.00
# Net Pay: $1,500.00

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is DA3D-4B70
#
#  Directory of C:\Users\aaa24h\repos\lis5377\a1
#
# 01/17/2026  04:34 AM    <DIR>          .
# 01/17/2026  02:00 AM    <DIR>          ..
# 01/17/2026  04:20 AM    <DIR>          .ipynb_checkpoints
# 01/17/2026  04:20 AM    <DIR>          .virtual_documents
# 01/17/2026  04:05 AM             2,156 a1_paycheck_calculator.ipynb
# 01/17/2026  03:31 AM               665 a1_paycheck_calculator.py
# 01/17/2026  04:25 AM                78 demo.py
# 01/17/2026  03:33 AM            25,822 idle_paycheck.png
# 01/17/2026  04:07 AM            64,814 jupyter_paycheck.png
# 01/17/2026  04:11 AM             1,307 README.md
# 01/17/2026  04:34 AM             1,568 run_py_files_in_jupyter_lab.ipynb
# 01/17/2026  04:31 AM            75,954 run_py_files_jupyter.png
# 01/17/2026  03:54 AM            66,906 vscode_paycheck.png
#                9 File(s)        239,270 bytes
#                4 Dir(s)  896,398,139,392 bytes free

# %%
# %%writefile demo.py
print("Hello, This is Ayansewa Adedeji. I am a librarian and a programmer!")
# Out:
# Overwriting demo.py

# %%
# %run demo.py
# Out:
# Hello, This is Ayansewa Adedeji. I am a librarian and a programmer!
